# %% [markdown]
# # Overfitting and Early Stopping

# %% [markdown]
# ### Importing the libraries

# %%
import matplotlib.pyplot as plt
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, load_img

# %% [markdown]
# ## Data Preprocessing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)
training_set = train_datagen.flow_from_directory('fruit_dataset/train',
                                                 target_size = (200, 200),
                                                 batch_size = 8,
                                                 class_mode = 'categorical')
# Out:
# Found 240 images belonging to 4 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('fruit_dataset/test',
                                            target_size = (200, 200),
                                            batch_size = 8,
                                            class_mode = 'categorical')
# Out:
# Found 60 images belonging to 4 classes.

# %%
# Visualizing Training data
plt.imshow(load_img('fruit_dataset/train/apple/apple_1.jpg'))

# %% [markdown]
# ## Building the CNN

# %% [markdown]
# ### Dropout
# Another technique to reduce overfitting is to introduce dropout regularization to the network.
#
# When you apply dropout to a layer, it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.
#
# Let's create a new neural network with tf.keras.layers.Dropout before training it using the augmented images:

# %%
# Creating a Sequential model
# ** We can try to use 'tanh' activation in all the conv2D layers **
model= Sequential()
model.add(Conv2D(kernel_size=(3,3), filters=32, activation='relu', input_shape=(200,200,3,)))
model.add(MaxPool2D(2,2))
model.add(Conv2D(filters=30,kernel_size = (3,3),activation='relu'))
model.add(MaxPool2D(2,2))
model.add(Conv2D(filters=30,kernel_size = (3,3),activation='relu'))
model.add(Dropout(0.2)),
model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(4,activation = 'softmax'))
    
model.compile(
              loss='categorical_crossentropy', 
              metrics=['acc'],
              optimizer='adam'
             )

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 198, 198, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 97, 97, 30)        8670
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 30)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 30)        8130
# _________________________________________________________________
# dropout (Dropout)            (None, 46, 46, 30)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 63480)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8125568
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 8,151,780
# Trainable params: 8,151,780
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
from keras import callbacks
# This callback will stop the training when there is no improvement in
callback = callbacks.EarlyStopping(monitor='loss', patience=3)

# Training the model
history = model.fit(x = training_set, validation_data = test_set ,epochs=50, callbacks=[callback])
# Out:
# Epoch 1/50
# 10/30 [=========>....................] - ETA: 8s - loss: 1.7566 - acc: 0.3000
# C:\Users\avivg\anaconda3\lib\site-packages\PIL\Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 30/30 [==============================] - 15s 511ms/step - loss: 1.2215 - acc: 0.5042 - val_loss: 1.0470 - val_acc: 0.5833
# Epoch 2/50
# 30/30 [==============================] - 12s 416ms/step - loss: 0.6870 - acc: 0.7500 - val_loss: 0.6794 - val_acc: 0.8000
# Epoch 3/50
# 30/30 [==============================] - 13s 450ms/step - loss: 0.5416 - acc: 0.8000 - val_loss: 0.7559 - val_acc: 0.8000
# Epoch 4/50
# 30/30 [==============================] - 15s 488ms/step - loss: 0.5106 - acc: 0.7875 - val_loss: 0.5858 - val_acc: 0.8000
# Epoch 5/50
# 30/30 [==============================] - 13s 449ms/step - loss: 0.5378 - acc: 0.8208 - val_loss: 0.7177 - val_acc: 0.7167
# Epoch 6/50
# 30/30 [==============================] - 14s 460ms/step - loss: 0.4631 - acc: 0.8250 - val_loss: 0.6478 - val_acc: 0.8000
# Epoch 7/50
# 30/30 [==============================] - 13s 423ms/step - loss: 0.2877 - acc: 0.8875 - val_loss: 0.7687 - val_acc: 0.8333
# Epoch 8/50
# 30/30 [==============================] - 13s 445ms/step - loss: 0.3158 - acc: 0.8833 - val_loss: 0.5909 - val_acc: 0.9000
# Epoch 9/50
# 30/30 [==============================] - 13s 420ms/step - loss: 0.3568 - acc: 0.8667 - val_loss: 0.7084 - val_acc: 0.7333
# Epoch 10/50
# 30/30 [==============================] - 14s 457ms/step - loss: 0.3486 - acc: 0.8583 - val_loss: 0.5967 - val_acc: 0.9000

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
accuracy = round(history.history['acc'][-1], 2)
print(f'The model accuracy is: {accuracy}')
# Out:
# The model accuracy is: 0.86

# %% [markdown]
# ## Making a single prediction

# %%
fruit_classes = {0: 'banana', 1: 'apple', 2: 'mixed', 3: 'orange'}

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('fruit_dataset/test/apple/apple_81.jpg', target_size = (200, 200))

test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
training_set.class_indices
pred = fruit_classes[result[0][0]]

print(f'The model predicted: {pred}')
# Out:
# The model predicted: banana
